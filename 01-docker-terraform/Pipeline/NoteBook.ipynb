# %%
import pandas as pd

# %%
prefix = "https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow"
url = f'{prefix}/yellow_tripdata_2021-01.csv.gz'

# %%
df = pd.read_csv(url)
# Out:
# /tmp/ipykernel_58861/4176769558.py:1: DtypeWarning: Columns (0: store_and_fwd_flag) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1       1.0  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2       1.0  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3       1.0  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4       2.0  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           2.0          8.0    3.0      0.5        0.00           0.0
# 1           2.0          3.0    0.5      0.5        0.00           0.0
# 2           1.0         42.0    0.5      0.5        8.65           0.0
# 3           1.0         29.0    0.5      0.5        6.05           0.0
# 4           1.0         16.5    0.5      0.5        4.06           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3         11.80                   2.5
# 1                    0.3          4.30                   0.0
# 2                    0.3         51.95                   0.0
# 3                    0.3         36.35                   0.0
# 4                    0.3         24.36                   2.5

# %%
len(df)
# Out:
# 1369765

# %%
df['VendorID']
# Out:
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          2.0
#           ...
# 1369760    NaN
# 1369761    NaN
# 1369762    NaN
# 1369763    NaN
# 1369764    NaN
# Name: VendorID, Length: 1369765, dtype: float64

# %%
df.dtypes
# Out:
# VendorID                 float64
# tpep_pickup_datetime         str
# tpep_dropoff_datetime        str
# passenger_count          float64
# trip_distance            float64
# RatecodeID               float64
# store_and_fwd_flag           str
# PULocationID               int64
# DOLocationID               int64
# payment_type             float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %%
df.shape
# Out:
# (1369765, 18)

# %%
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}

parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

df = pd.read_csv(
    url,
    dtype=dtype,
    parse_dates=parse_dates
)

# %%
len(df)
# Out:
# 1369765

# %%
df['tpep_dropoff_datetime']
# Out:
# 0         2021-01-01 00:36:12
# 1         2021-01-01 00:52:19
# 2         2021-01-01 01:11:06
# 3         2021-01-01 00:31:01
# 4         2021-01-01 00:48:21
#                   ...
# 1369760   2021-01-25 08:49:32
# 1369761   2021-01-25 09:04:00
# 1369762   2021-01-25 08:53:00
# 1369763   2021-01-25 08:50:00
# 1369764   2021-01-25 08:50:00
# Name: tpep_dropoff_datetime, Length: 1369765, dtype: datetime64[us]

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# 1           0.20           1                  N           238           151
# 2          14.70           1                  N           132           165
# 3          10.60           1                  N           138           132
# 4           4.94           1                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          8.0    3.0      0.5        0.00           0.0
# 1             2          3.0    0.5      0.5        0.00           0.0
# 2             1         42.0    0.5      0.5        8.65           0.0
# 3             1         29.0    0.5      0.5        6.05           0.0
# 4             1         16.5    0.5      0.5        4.06           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge
# 0                    0.3         11.80                   2.5
# 1                    0.3          4.30                   0.0
# 2                    0.3         51.95                   0.0
# 3                    0.3         36.35                   0.0
# 4                    0.3         24.36                   2.5

# %%
# !uv add sqlalchemy
# Out:
# Resolved 117 packages in 2.38s
# ⠸ Preparing packages... (0/2)
# ⠸ Preparing packages... (0/2)-------------------     0 B/598.54 KiB
# ⠸ Preparing packages... (0/2)------------------- 14.88 KiB/598.54 KiB
# ⠸ Preparing packages... (0/2)------------------- 14.88 KiB/598.54 KiB
# greenlet             ------------------------------ 14.88 KiB/598.54 KiB
# ⠸ Preparing packages... (0/2)-------------------     0 B/3.14 MiB
# greenlet             ------------------------------ 14.88 KiB/598.54 KiB
# ⠸ Preparing packages... (0/2)------------------- 14.91 KiB/3.14 MiB
# greenlet             ------------------------------ 25.42 KiB/598.54 KiB
# ⠼ Preparing packages... (0/2)------------------- 14.91 KiB/3.14 MiB
# greenlet             ------------------------------ 25.42 KiB/598.54 KiB
# ⠼ Preparing packages... (0/2)------------------- 14.91 KiB/3.14 MiB
# greenlet             ------------------------------ 28.13 KiB/598.54 KiB
# ⠼ Preparing packages... (0/2)------------------- 14.91 KiB/3.14 MiB
# greenlet             ------------------------------ 28.13 KiB/598.54 KiB
# ⠼ Preparing packages... (0/2)------------------- 25.76 KiB/3.14 MiB
# greenlet             ------------------------------ 38.98 KiB/598.54 KiB
# ⠼ Preparing packages... (0/2)------------------- 25.76 KiB/3.14 MiB
# greenlet             ------------------------------ 38.98 KiB/598.54 KiB
# ⠼ Preparing packages... (0/2)------------------- 39.32 KiB/3.14 MiB
# greenlet             ------------------------------ 54.98 KiB/598.54 KiB
# ⠼ Preparing packages... (0/2)------------------- 39.32 KiB/3.14 MiB
# greenlet             ------------------------------ 54.98 KiB/598.54 KiB
# ⠼ Preparing packages... (0/2)------------------- 55.32 KiB/3.14 MiB
# greenlet             ------------------------------ 70.98 KiB/598.54 KiB
# ⠼ Preparing packages... (0/2)------------------- 55.32 KiB/3.14 MiB
# greenlet             ------------------------------ 70.98 KiB/598.54 KiB
# ⠼ Preparing packages... (0/2)------------------- 71.32 KiB/3.14 MiB
# greenlet             ------------------------------ 70.98 KiB/598.54 KiB
# ⠼ Preparing packages... (0/2)------------------- 78.91 KiB/3.14 MiB
# greenlet             ------------------------------ 78.88 KiB/598.54 KiB
# ⠼ Preparing packages... (0/2)------------------- 78.91 KiB/3.14 MiB
# greenlet             ------------------------------ 94.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 78.91 KiB/3.14 MiB
# greenlet             ------------------------------ 94.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 78.91 KiB/3.14 MiB
# greenlet             ------------------------------ 94.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 94.91 KiB/3.14 MiB
# greenlet             ------------------------------ 110.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 94.91 KiB/3.14 MiB
# greenlet             ------------------------------ 110.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 110.91 KiB/3.14 MiB
# greenlet             ------------------------------ 126.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 110.91 KiB/3.14 MiB
# greenlet             ------------------------------ 126.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 126.91 KiB/3.14 MiB
# greenlet             ------------------------------ 142.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 126.91 KiB/3.14 MiB
# greenlet             ------------------------------ 142.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 142.80 KiB/3.14 MiB
# greenlet             ------------------------------ 142.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 142.91 KiB/3.14 MiB
# greenlet             ------------------------------ 158.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 142.91 KiB/3.14 MiB
# greenlet             ------------------------------ 174.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 142.91 KiB/3.14 MiB
# greenlet             ------------------------------ 190.88 KiB/598.54 KiB
# ⠴ Preparing packages... (0/2)------------------- 142.91 KiB/3.14 MiB
# greenlet             ------------------------------ 238.88 KiB/598.54 KiB
# ⠦ Preparing packages... (0/2)------------------- 174.91 KiB/3.14 MiB
# greenlet             ------------------------------ 350.88 KiB/598.54 KiB
# ⠦ Preparing packages... (0/2)------------------- 222.91 KiB/3.14 MiB
# greenlet             ------------------------------ 366.88 KiB/598.54 KiB
# ⠦ Preparing packages... (0/2)------------------- 238.91 KiB/3.14 MiB
# greenlet             ------------------------------ 440.56 KiB/598.54 KiB
# ⠦ Preparing packages... (0/2)------------------- 334.91 KiB/3.14 MiB
# greenlet             ------------------------------ 520.56 KiB/598.54 KiB
# ⠦ Preparing packages... (0/2)------------------- 456.56 KiB/3.14 MiB
# ⠧ Preparing packages... (1/2)------------------- 520.56 KiB/3.14 MiB
# ⠧ Preparing packages... (1/2)------------------- 664.56 KiB/3.14 MiB
# ⠧ Preparing packages... (1/2)------------------- 824.56 KiB/3.14 MiB
# ⠧ Preparing packages... (1/2)------------------- 888.56 KiB/3.14 MiB
# ⠇ Preparing packages... (1/2)------------------- 904.56 KiB/3.14 MiB
# ⠇ Preparing packages... (1/2)------------------- 1.02 MiB/3.14 MiB
# ⠇ Preparing packages... (1/2)m------------------ 1.27 MiB/3.14 MiB
# ⠇ Preparing packages... (1/2)---------------- 1.47 MiB/3.14 MiB
# ⠋ Preparing packages... (1/2)m-------------- 1.69 MiB/3.14 MiB
# ⠋ Preparing packages... (1/2)0m------------- 1.87 MiB/3.14 MiB
# ⠋ Preparing packages... (1/2)----------- 2.02 MiB/3.14 MiB
# ⠋ Preparing packages... (1/2)---------- 2.20 MiB/3.14 MiB
# ⠙ Preparing packages... (1/2)---------- 2.46 MiB/3.14 MiB
# ⠙ Preparing packages... (1/2)---------- 2.61 MiB/3.14 MiB
# ⠙ Preparing packages... (1/2)---------- 2.81 MiB/3.14 MiB
# Prepared 2 packages in 1.93s
# Installed 2 packages in 11ms
#  + greenlet==3.3.1
#  + sqlalchemy==2.0.46

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 2
#       1 from sqlalchemy import create_engine
# ----> 2 engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/WorkSpace/Data-Engineering-Zoomcamp-2026/01-docker-terraform/Pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~/WorkSpace/Data-Engineering-Zoomcamp-2026/01-docker-terraform/Pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/engine/create.py:617, in create_engine(url, **kwargs)
#     615         if k in kwargs:
#     616             dbapi_args[k] = pop_kwarg(k)
# --> 617     dbapi = dbapi_meth(**dbapi_args)
#     619 dialect_args["dbapi"] = dbapi
#     621 dialect_args.setdefault("compiler_linting", compiler.NO_LINTING)
#
# File ~/WorkSpace/Data-Engineering-Zoomcamp-2026/01-docker-terraform/Pipeline/.venv/lib/python3.13/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:696, in PGDialect_psycopg2.import_dbapi(cls)
#     694 @classmethod
#     695 def import_dbapi(cls):
# --> 696     import psycopg2
#     698     return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
# !uv add psycopg2-binary
# Out:
# Resolved 118 packages in 854ms
# ⠸ Preparing packages... (0/1)
# ⠸ Preparing packages... (0/1)-------------------     0 B/3.97 MiB
# ⠸ Preparing packages... (0/1)------------------- 16.00 KiB/3.97 MiB
# ⠼ Preparing packages... (0/1)------------------- 32.00 KiB/3.97 MiB
# ⠼ Preparing packages... (0/1)------------------- 32.00 KiB/3.97 MiB
# ⠼ Preparing packages... (0/1)------------------- 40.70 KiB/3.97 MiB
# ⠼ Preparing packages... (0/1)------------------- 43.40 KiB/3.97 MiB
# ⠼ Preparing packages... (0/1)------------------- 54.25 KiB/3.97 MiB
# ⠼ Preparing packages... (0/1)------------------- 62.39 KiB/3.97 MiB
# ⠼ Preparing packages... (0/1)------------------- 64.00 KiB/3.97 MiB
# ⠼ Preparing packages... (0/1)------------------- 80.00 KiB/3.97 MiB
# ⠼ Preparing packages... (0/1)------------------- 82.99 KiB/3.97 MiB
# ⠼ Preparing packages... (0/1)------------------- 98.99 KiB/3.97 MiB
# ⠼ Preparing packages... (0/1)------------------- 114.99 KiB/3.97 MiB
# ⠼ Preparing packages... (0/1)------------------- 128.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 144.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 144.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 160.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 176.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 192.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 208.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 224.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 240.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 256.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 272.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 288.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 304.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 320.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 336.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 352.00 KiB/3.97 MiB
# ⠴ Preparing packages... (0/1)------------------- 368.00 KiB/3.97 MiB
# ⠦ Preparing packages... (0/1)------------------- 384.00 KiB/3.97 MiB
# ⠦ Preparing packages... (0/1)------------------- 448.00 KiB/3.97 MiB
# ⠦ Preparing packages... (0/1)------------------- 587.00 KiB/3.97 MiB
# ⠦ Preparing packages... (0/1)------------------- 779.00 KiB/3.97 MiB
# ⠧ Preparing packages... (0/1)------------------- 987.00 KiB/3.97 MiB
# ⠧ Preparing packages... (0/1)------------------- 1.14 MiB/3.97 MiB
# ⠧ Preparing packages... (0/1)------------------- 1.35 MiB/3.97 MiB
# ⠧ Preparing packages... (0/1)------------------- 1.57 MiB/3.97 MiB
# ⠇ Preparing packages... (0/1)2m----------------- 1.85 MiB/3.97 MiB
# ⠇ Preparing packages... (0/1)--------------- 2.08 MiB/3.97 MiB
# ⠇ Preparing packages... (0/1)0m------------- 2.33 MiB/3.97 MiB
# ⠋ Preparing packages... (0/1)----------- 2.52 MiB/3.97 MiB
# ⠋ Preparing packages... (0/1)---------- 2.70 MiB/3.97 MiB
# ⠋ Preparing packages... (0/1)---------- 2.71 MiB/3.97 MiB
# ⠋ Preparing packages... (0/1)---------- 2.93 MiB/3.97 MiB
# ⠋ Preparing packages... (0/1)---------- 3.16 MiB/3.97 MiB
# ⠋ Preparing packages... (0/1)---------- 3.41 MiB/3.97 MiB
# ⠙ Preparing packages... (0/1)---------- 3.65 MiB/3.97 MiB
# Prepared 1 package in 1.86s
# Installed 1 package in 3ms9.11
#  + psycopg2-binary==2.9.11

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge]
# Index: []

# %%
df.head(0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv(
    url,
    dtype=dtype,
    parse_dates=parse_dates,
    iterator=True,
    chunksize=100000,
)

# %%
# !uv add tqdm
# Out:
# Resolved 119 packages in 1.91s
# ⠸ Preparing packages... (0/1)
# ⠸ Preparing packages... (0/1)-------------------     0 B/76.70 KiB
# ⠸ Preparing packages... (0/1)------------------- 14.88 KiB/76.70 KiB
# ⠸ Preparing packages... (0/1)m------------------ 30.88 KiB/76.70 KiB
# ⠸ Preparing packages... (0/1)m-------------- 43.37 KiB/76.70 KiB
# ⠼ Preparing packages... (0/1)----------- 48.79 KiB/76.70 KiB
# ⠼ Preparing packages... (0/1)----------- 48.79 KiB/76.70 KiB
# ⠼ Preparing packages... (0/1)---------- 59.64 KiB/76.70 KiB
# ⠼ Preparing packages... (0/1)---------- 75.64 KiB/76.70 KiB
# ⠼ Preparing packages... (0/1)---------- 75.92 KiB/76.70 KiB
# ⠼ Preparing packages... (0/1)---------- 76.70 KiB/76.70 KiB
# Prepared 1 package in 633ms
# Installed 1 package in 6ms
#  + tqdm==4.67.1

# %%
from tqdm import tqdm

# %%
for df_chunk in tqdm(df_iter):
    df_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# 14it [01:30,  6.48s/it]
# Bad pipe message: %s [b' 10.0; Win64; x64; rv:147.0) Gecko/20100101 Firefox/147.0\r\nAccept: text/html,']
# Bad pipe message: %s [b'plication/xhtml+xml,application/xml;q=0.9,*/*;q=0.8\r\nAccept-Language: en-US,en;q=0.9\r\nAccept-Enc']
# Bad pipe message: %s [b'ing: gzip, deflate, br, zstd\r\nConnection: keep-alive\r\nCookie: _xsrf=2|a4860f03|2080d911dbb55fbc01c94754bb37367']
# Bad pipe message: %s [b'1769413215; username-127-0-0-1-8888="2|1:0|10:1']
# Bad pipe message: %s [b'9413239|23:username-127-0-0-1-8888|204:eyJ1c2VybmFtZSI']
# Bad pipe message: %s [b'CJkMjBjZDUyNmVmYjA0ZmM5YWM5NjRmYTE3MDk3NzllYiIsICJuYW', b'IjogIkFub255bW91cyBUaGVseGlub2UiLCAiZGlzcGxheV9u']
# Bad pipe message: %s [b'1lIjogIkFub255bW91cyBUaGVseGlub2UiLCAiaW5pdGlhbHMiOiAiQVQiLCAiY29sb3IiOiBudWxsfQ==|f4f89', b'695a5c06e51272d457ab9a5607aa7f240e44bb81de9af36e37291c6a3"\r\nUpgrade-Insecure-Requests: 1\r\nSec-Fetch-']
# Bad pipe message: %s [b'(Windows NT 10.0; Win64; x64; rv:147.0) Gecko/2']
# Bad pipe message: %s [b'00101 Firefox/147.0\r\nAccept: image/avif,image/w', b'p,image/png,image/svg+xml,image/*;q=0.8,*/*;q=0.5\r\nAccept-Language: en-US,en;q=0.9\r\nAccept-Encoding:']
# Bad pipe message: %s [b'zip, deflate, br, zstd\r\nConnect', b'n: keep-alive\r\nReferer: http://127.0.0.1:34029/\r\nCookie: _xsrf=2|a4860f03|2080d911dbb55fbc01c94754bb3736', b'|1769413215; username-127-0-0-1-8888="2|1:0|10:1769413']
# Bad pipe message: %s [b'9|23:username-127-0-0-1-8888|204:eyJ1c2VybmFtZSI6', b'JkMjBjZDUyNmVmYjA0ZmM5YWM5NjRmYTE3MDk3NzllYiIsICJuYW1lIjogIkFub255bW91cy', b'aGVseGlub2UiLCAiZGlzcGxheV9uYW1lIjogIkFub255bW91cyBUaGVseGlub2UiL', b'iaW5pdGlhbHMiOiAiQVQiLCAiY29sb3IiOiBudWxsfQ==|f4f89e8695a5c06e5127', b'457ab9a5607aa7f240e44bb81de9af36e37291c6a3"\r\nSec-']
# Bad pipe message: %s [b'tch-Dest: image\r\nSec-Fetch-Mode: no-cors\r\nSec-Fetch-Site: same-origin', b'Priority: u=']
